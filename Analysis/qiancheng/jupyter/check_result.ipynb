# %% [markdown]
# > 主要目的是检查对浅橙使用random forest算法获取的maxent_id比例过低的问题：
# - 模型在全集上的预测的结果，没有达到浅橙5%-10%的比例，需要检查一下原因。
# - 理论上模型预测出的1都应该出现在后续给浅橙的maxent_id里面，而不是实际中的只有几个。
#
# 这一版针对的是给浅橙报告训练模型所对应的数据

# %% [markdown]
# ### label为1的情况下的训练数据集聚合数据的检查

# %%
from __future__ import print_function, division
from Utils.qiancheng.get_data import read_data
from Utils.common.MultiColumnLabelEncoder import MultiColumnLabelEncoder
import numpy as np
import pandas as pd
from Algorithm.qiancheng_tree import qiancheng_tree_rf
from Utils.common.transfer_event_dev import transfer_event_to_device
import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/chaoxu/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def df_os(df,os='ios'):
    df = df.loc[df.os == os]
    bool_cols = df.select_dtypes(include=[np.bool_]).columns.tolist()
    obj_cols = df.select_dtypes(include=[np.object_]).columns.tolist()
    encoder_cols = bool_cols + obj_cols
    if 'maxent_id' in encoder_cols:
        encoder_cols.remove('maxent_id')
    df = MultiColumnLabelEncoder(columns=encoder_cols).fit_transform(df)
    if os == 'ios':
        col_drop = ['os','maxent_id', 'aid_loan', 'imei_loan', 'mac_loan', 'imei_counts', 'mac_counts', 'aid_counts']
    else:
        col_drop = ['os','maxent_id', 'idfa_loan', 'idfa_counts', 'idfv_counts', 'imei_loan']

    df = df.drop(col_drop,axis=1)
    return df

# %%
file_name = "/Users/chaoxu/code/local-spark/Data/qiancheng_data/qiancheng_sample_new_merge_0.09/data.csv"
df = read_data(file_name)

# %%
df_o = pd.read_csv(file_name)

# %%
df_o.event_type.value_counts()
# Out:
# ACT    28569
# Name: event_type, dtype: int64

# %% [markdown]
# #### 数据准备

# %% [markdown]
# ##### 读入训练数据集

# %%
df_ios = df_os(df=df,os='ios')

# %%
df_ios_chk=df_ios.loc[df_ios.label == 1]

# %%
df_android = df_os(df=df,os='android')

# %%
df_android_chk=df_android.loc[df_android.label == 1]

# %% [markdown]
# ##### 读入线上所有数据

# %%
import re

def read_data_ol(path):
    df = pd.read_csv(path)
    anormaly = re.compile('.*anomaly$')
    anormaly_match = np.vectorize(lambda x: bool(anormaly.match(x)))
    anormaly_cols = df.columns.values[anormaly_match(df.columns.values)]
    value = re.compile('.*value$')
    value_match = np.vectorize(lambda x: bool(value.match(x)))
    value_cols = df.columns.values[value_match(df.columns.values)]
    count = re.compile('.*counts$')
    count_match = np.vectorize(lambda x: bool(count.match(x)))
    count_cols = df.columns.values[count_match(df.columns.values)]
    loan = re.compile('.*loan$')
    loan_match = np.vectorize(lambda x: bool(loan.match(x)))
    loan_cols = df.columns.values[loan_match(df.columns.values)]
#     df[anormaly_cols] = df[anormaly_cols].fillna(1)
#     df[value_cols] = df[value_cols].fillna(1)
#     df[loan_cols] = df[loan_cols].fillna(0)
#     df[count_cols] = df[count_cols].fillna(0)
    df['label'] = df['label'].fillna(0)
    old_names = anormaly_cols.tolist() + value_cols.tolist()
    new_names = map(lambda x: x.replace("_", "."), old_names)
    df.rename(columns=dict(zip(old_names, new_names)), inplace=True)
    print(df.columns[df.isnull().any()])
    return df

# %%
file_ol =  "/Users/chaoxu/code/local-spark/Data/qiancheng_data/qiancheng_dev_merge/data.csv"

# %%
df_ol = read_data_ol(file_ol)
# Out:
# Index([u'cracked.anomaly', u'did.15m.anomaly', u'did.1d.anomaly',
#        u'did.1h.anomaly', u'did.1m.anomaly', u'did.5m.anomaly',
#        u'did.6h.anomaly', u'did.7d.anomaly', u'idcIP.anomaly',
#        u'ipGeo.15m.anomaly', u'ipGeo.1d.anomaly', u'ipGeo.1h.anomaly',
#        u'ipGeo.1m.anomaly', u'ipGeo.5m.anomaly', u'ipGeo.6h.anomaly',
#        u'ipGeo.7d.anomaly', u'ipSeg24.15m.anomaly', u'ipSeg24.1d.anomaly',
#        u'ipSeg24.1h.anomaly', u'ipSeg24.1m.anomaly', u'ipSeg24.5m.anomaly',
#        u'ipSeg24.6h.anomaly', u'ipSeg24.7d.anomaly', u'maxentID.15m.anomaly',
#        u'maxentID.1d.anomaly', u'maxentID.1h.anomaly', u'maxentID.1m.anomaly',
#        u'maxentID.5m.anomaly', u'maxentID.6h.anomaly', u'maxentID.7d.anomaly',
#        u'proxyIP.anomaly', u'uaMismatch.anomaly', u'aid_loan', u'idfa_loan',
#        u'imei_loan', u'mac_loan', u'did.15m.value', u'did.1d.value',
#        u'did.1h.value', u'did.1m.value', u'did.5m.value', u'did.6h.value',
#        u'did.7d.value', u'ipGeo.15m.value', u'ipGeo.1d.value',
#        u'ipGeo.1h.value', u'ipGeo.1m.value', u'ipGeo.5m.value',
#        u'ipGeo.6h.value', u'ipGeo.7d.value', u'ipSeg24.15m.value',
#        u'ipSeg24.1d.value', u'ipSeg24.1h.value', u'ipSeg24.1m.value',
#        u'ipSeg24.5m.value', u'ipSeg24.6h.value', u'ipSeg24.7d.value',
#        u'maxentID.15m.value', u'maxentID.1d.value', u'maxentID.1h.value',
#        u'maxentID.1m.value', u'maxentID.5m.value', u'maxentID.6h.value',
#        u'maxentID.7d.value', u'mcid_counts', u'imei_counts', u'mac_counts',
#        u'aid_counts', u'idfa_counts', u'idfv_counts'],
#       dtype='object')

# %%
df_ol_ios = df_os(df=df_ol,os='ios')

# %%
df_ol_ios_chk=df_ol_ios.loc[df_ol_ios.label == 1]

# %% [markdown]
# ##### 检查ios

# %% [markdown]
# - anomaly columns检查

# %%
anormaly = re.compile('.*anomaly$')
anormaly_match = np.vectorize(lambda x: bool(anormaly.match(x)))
anormaly_cols = df_ios_chk.columns.values[anormaly_match(df_ios_chk.columns.values)]
value = re.compile('.*value$')
value_match = np.vectorize(lambda x: bool(value.match(x)))
value_cols = df_ios_chk.columns.values[value_match(df_ios_chk.columns.values)]
count = re.compile('.*counts$')
count_match = np.vectorize(lambda x: bool(count.match(x)))
count_cols = df_ios_chk.columns.values[count_match(df_ios_chk.columns.values)]
loan = re.compile('.*loan$')
loan_match = np.vectorize(lambda x: bool(loan.match(x)))
loan_cols = df_ios_chk.columns.values[loan_match(df_ios_chk.columns.values)]

# %%
print(df_ios_chk.shape)
print(df_ol_ios_chk.shape)
# Out:
# (159, 68)
# (159, 68)

# %%
a = df_ios_chk['maxentID.6h.anomaly'].describe()
a.values
# Out:
# array([ 159.        ,    1.03773585,    0.19115877,    1.        ,
#           1.        ,    1.        ,    1.        ,    2.        ])

# %%
anomaly_dif_cols = []
for col in anormaly_cols:
    print("column:{0} description:\n".format(col))
    local_desc = df_ios_chk[col].describe()
    print(local_desc)
    ol_desc = df_ol_ios_chk[col].describe()
    print(ol_desc)
    if not np.allclose(local_desc.values,ol_desc.values,rtol=1e-6):
        print("!!!{0} desc is not same".format(col))
        anomaly_dif_cols.append(col)
    print("-----------------------\n")
    print("\n")
print("oline anormaly cols is not same as local:\n{0}".format(anomaly_dif_cols))
# Out:
# column:maxentID.6h.anomaly description:
#
# count    159.000000
# mean       1.037736
# std        0.191159
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: maxentID.6h.anomaly, dtype: float64
# count    159.000000
# mean       1.037736
# std        0.191159
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: maxentID.6h.anomaly, dtype: float64
# -----------------------
#
#
#
# column:did.5m.anomaly description:
#
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: did.5m.anomaly, dtype: float64
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: did.5m.anomaly, dtype: float64
# -----------------------
#
#
#
# column:maxentID.7d.anomaly description:
#
# count    159.000000
# mean       1.188679
# std        0.955794
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       11.000000
# Name: maxentID.7d.anomaly, dtype: float64
# count    159.000000
# mean       1.150943
# std        0.628326
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        5.000000
# Name: maxentID.7d.anomaly, dtype: float64
# !!!maxentID.7d.anomaly desc is not same
# -----------------------
#
#
#
# column:maxentID.5m.anomaly description:
#
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: maxentID.5m.anomaly, dtype: float64
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: maxentID.5m.anomaly, dtype: float64
# -----------------------
#
#
#
# column:cracked.anomaly description:
#
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: cracked.anomaly, dtype: float64
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: cracked.anomaly, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.1d.anomaly description:
#
# count    159.000000
# mean       1.044025
# std        0.283422
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: ipGeo.1d.anomaly, dtype: float64
# count    159.000000
# mean       1.044025
# std        0.283422
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: ipGeo.1d.anomaly, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.5m.anomaly description:
#
# count     159.000000
# mean      247.880503
# std       415.543267
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%       251.500000
# max      1000.000000
# Name: ipGeo.5m.anomaly, dtype: float64
# count     159.000000
# mean      179.679245
# std       359.822202
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%        60.000000
# max      1000.000000
# Name: ipGeo.5m.anomaly, dtype: float64
# !!!ipGeo.5m.anomaly desc is not same
# -----------------------
#
#
#
# column:did.15m.anomaly description:
#
# count    159.000000
# mean       1.018868
# std        0.136488
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: did.15m.anomaly, dtype: float64
# count    159.000000
# mean       1.018868
# std        0.136488
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: did.15m.anomaly, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.1h.anomaly description:
#
# count     159.000000
# mean       10.044025
# std        80.693070
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1000.000000
# Name: ipSeg24.1h.anomaly, dtype: float64
# count    159.000000
# mean       9.742138
# std       77.280454
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max      956.000000
# Name: ipSeg24.1h.anomaly, dtype: float64
# !!!ipSeg24.1h.anomaly desc is not same
# -----------------------
#
#
#
# column:ipGeo.7d.anomaly description:
#
# count    159.000000
# mean       1.056604
# std        0.506231
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        7.000000
# Name: ipGeo.7d.anomaly, dtype: float64
# count    159.000000
# mean       1.056604
# std        0.506231
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        7.000000
# Name: ipGeo.7d.anomaly, dtype: float64
# -----------------------
#
#
#
# column:uaMismatch.anomaly description:
#
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: uaMismatch.anomaly, dtype: float64
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: uaMismatch.anomaly, dtype: float64
# -----------------------
#
#
#
# column:did.7d.anomaly description:
#
# count    159.000000
# mean       1.169811
# std        1.056670
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       13.000000
# Name: did.7d.anomaly, dtype: float64
# count    159.000000
# mean       1.125786
# std        0.613582
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        6.000000
# Name: did.7d.anomaly, dtype: float64
# !!!did.7d.anomaly desc is not same
# -----------------------
#
#
#
# column:maxentID.15m.anomaly description:
#
# count    159.000000
# mean       1.025157
# std        0.157097
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: maxentID.15m.anomaly, dtype: float64
# count    159.000000
# mean       1.025157
# std        0.157097
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: maxentID.15m.anomaly, dtype: float64
# -----------------------
#
#
#
# column:did.6h.anomaly description:
#
# count    159.000000
# mean       1.069182
# std        0.357903
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: did.6h.anomaly, dtype: float64
# count    159.000000
# mean       1.069182
# std        0.357903
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: did.6h.anomaly, dtype: float64
# -----------------------
#
#
#
# column:maxentID.1d.anomaly description:
#
# count    159.000000
# mean       1.069182
# std        0.339760
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: maxentID.1d.anomaly, dtype: float64
# count    159.000000
# mean       1.069182
# std        0.339760
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: maxentID.1d.anomaly, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.15m.anomaly description:
#
# count     159.000000
# mean      484.301887
# std       486.695155
# min         1.000000
# 25%         1.000000
# 50%       236.000000
# 75%      1000.000000
# max      1000.000000
# Name: ipGeo.15m.anomaly, dtype: float64
# count     159.000000
# mean      374.308176
# std       459.088240
# min         1.000000
# 25%         1.000000
# 50%        15.000000
# 75%      1000.000000
# max      1000.000000
# Name: ipGeo.15m.anomaly, dtype: float64
# !!!ipGeo.15m.anomaly desc is not same
# -----------------------
#
#
#
# column:did.1h.anomaly description:
#
# count    159.000000
# mean       1.056604
# std        0.302841
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: did.1h.anomaly, dtype: float64
# count    159.000000
# mean       1.056604
# std        0.302841
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: did.1h.anomaly, dtype: float64
# -----------------------
#
#
#
# column:idcIP.anomaly description:
#
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: idcIP.anomaly, dtype: float64
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: idcIP.anomaly, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.1m.anomaly description:
#
# count     159.000000
# mean       25.000000
# std       133.269499
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1000.000000
# Name: ipGeo.1m.anomaly, dtype: float64
# count     159.000000
# mean       20.440252
# std       124.031927
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1000.000000
# Name: ipGeo.1m.anomaly, dtype: float64
# !!!ipGeo.1m.anomaly desc is not same
# -----------------------
#
#
#
# column:proxyIP.anomaly description:
#
# count    159.000000
# mean       6.056604
# std       61.930161
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max      782.000000
# Name: proxyIP.anomaly, dtype: float64
# count    159.000000
# mean       6.056604
# std       61.930161
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max      782.000000
# Name: proxyIP.anomaly, dtype: float64
# -----------------------
#
#
#
# column:maxentID.1h.anomaly description:
#
# count    159.000000
# mean       1.012579
# std        0.158610
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: maxentID.1h.anomaly, dtype: float64
# count    159.000000
# mean       1.012579
# std        0.158610
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: maxentID.1h.anomaly, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.1d.anomaly description:
#
# count    159.000000
# mean       1.779874
# std        2.401602
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       10.000000
# Name: ipSeg24.1d.anomaly, dtype: float64
# count    159.000000
# mean       1.729560
# std        2.310366
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       10.000000
# Name: ipSeg24.1d.anomaly, dtype: float64
# !!!ipSeg24.1d.anomaly desc is not same
# -----------------------
#
#
#
# column:ipSeg24.6h.anomaly description:
#
# count     159.000000
# mean       13.119497
# std        81.664361
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max      1000.000000
# Name: ipSeg24.6h.anomaly, dtype: float64
# count    159.000000
# mean      11.408805
# std       63.586601
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max      761.000000
# Name: ipSeg24.6h.anomaly, dtype: float64
# !!!ipSeg24.6h.anomaly desc is not same
# -----------------------
#
#
#
# column:did.1d.anomaly description:
#
# count    159.000000
# mean       1.075472
# std        0.382318
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: did.1d.anomaly, dtype: float64
# count    159.000000
# mean       1.075472
# std        0.382318
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: did.1d.anomaly, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.7d.anomaly description:
#
# count    159.000000
# mean       2.194969
# std        6.155658
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       66.000000
# Name: ipSeg24.7d.anomaly, dtype: float64
# count    159.000000
# mean       2.144654
# std        6.124072
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       66.000000
# Name: ipSeg24.7d.anomaly, dtype: float64
# !!!ipSeg24.7d.anomaly desc is not same
# -----------------------
#
#
#
# column:ipGeo.6h.anomaly description:
#
# count     159.000000
# mean      485.150943
# std       489.331631
# min         1.000000
# 25%         1.000000
# 50%       126.000000
# 75%      1000.000000
# max      1000.000000
# Name: ipGeo.6h.anomaly, dtype: float64
# count     159.000000
# mean      358.119497
# std       460.862391
# min         1.000000
# 25%         1.000000
# 50%        15.000000
# 75%      1000.000000
# max      1000.000000
# Name: ipGeo.6h.anomaly, dtype: float64
# !!!ipGeo.6h.anomaly desc is not same
# -----------------------
#
#
#
# column:ipSeg24.1m.anomaly description:
#
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: ipSeg24.1m.anomaly, dtype: float64
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: ipSeg24.1m.anomaly, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.5m.anomaly description:
#
# count     159.000000
# mean       14.333333
# std       111.894145
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1000.000000
# Name: ipSeg24.5m.anomaly, dtype: float64
# count     159.000000
# mean        8.094340
# std        79.576394
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1000.000000
# Name: ipSeg24.5m.anomaly, dtype: float64
# !!!ipSeg24.5m.anomaly desc is not same
# -----------------------
#
#
#
# column:did.1m.anomaly description:
#
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: did.1m.anomaly, dtype: float64
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: did.1m.anomaly, dtype: float64
# -----------------------
#
#
#
# column:maxentID.1m.anomaly description:
#
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: maxentID.1m.anomaly, dtype: float64
# count    159.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: maxentID.1m.anomaly, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.1h.anomaly description:
#
# count     159.000000
# mean      281.031447
# std       423.451571
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%       635.500000
# max      1000.000000
# Name: ipGeo.1h.anomaly, dtype: float64
# count     159.000000
# mean      220.591195
# std       385.431703
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%       217.000000
# max      1000.000000
# Name: ipGeo.1h.anomaly, dtype: float64
# !!!ipGeo.1h.anomaly desc is not same
# -----------------------
#
#
#
# column:ipSeg24.15m.anomaly description:
#
# count     159.000000
# mean       33.396226
# std       161.467441
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1000.000000
# Name: ipSeg24.15m.anomaly, dtype: float64
# count     159.000000
# mean       24.081761
# std       137.899155
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1000.000000
# Name: ipSeg24.15m.anomaly, dtype: float64
# !!!ipSeg24.15m.anomaly desc is not same
# -----------------------
#
#
#
# oline anormaly cols is not same as local:
# ['maxentID.7d.anomaly', 'ipGeo.5m.anomaly', 'ipSeg24.1h.anomaly', 'did.7d.anomaly', 'ipGeo.15m.anomaly', 'ipGeo.1m.anomaly', 'ipSeg24.1d.anomaly', 'ipSeg24.6h.anomaly', 'ipSeg24.7d.anomaly', 'ipGeo.6h.anomaly', 'ipSeg24.5m.anomaly', 'ipGeo.1h.anomaly', 'ipSeg24.15m.anomaly']

# %% [markdown]
# 发生变化的anormaly cols:
#
# ['maxentID.7d.anomaly', 'ipGeo.5m.anomaly', 'ipSeg24.1h.anomaly', 'did.7d.anomaly', 'ipGeo.15m.anomaly', 'ipGeo.1m.anomaly', 'ipSeg24.1d.anomaly', 'ipSeg24.6h.anomaly', 'ipSeg24.7d.anomaly', 'ipGeo.6h.anomaly', 'ipSeg24.5m.anomaly', 'ipGeo.1h.anomaly', 'ipSeg24.15m.anomaly']

# %% [markdown]
# - value columns检查

# %%
value_dif_cols = []
for col in value_cols:
    print("column:{0} description:\n".format(col))
    local_desc = df_ios_chk[col].describe()
    print(local_desc)
    ol_desc = df_ol_ios_chk[col].describe()
    print(ol_desc)
    if not np.allclose(local_desc.values,ol_desc.values,rtol=1e-6):
        print("!!!{0} desc is not same".format(col))
        value_dif_cols.append(col)
    print("-----------------------\n")
    print("\n")
print("oline value cols is not same as local:\n{0}".format(value_dif_cols))
# Out:
# column:ipSeg24.15m.value description:
#
# count    159.000000
# mean       3.137636
# std        4.174800
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        3.500000
# max       33.000000
# Name: ipSeg24.15m.value, dtype: float64
# count    159.000000
# mean       3.137636
# std        4.174800
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        3.500000
# max       33.000000
# Name: ipSeg24.15m.value, dtype: float64
# -----------------------
#
#
#
# column:cracked.value description:
#
# count    159.000000
# mean       0.031447
# std        0.175073
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: cracked.value, dtype: float64
# count    159.000000
# mean       0.031447
# std        0.175073
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: cracked.value, dtype: float64
# -----------------------
#
#
#
# column:idcIP.value description:
#
# count    159.000000
# mean       0.004193
# std        0.052870
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.666667
# Name: idcIP.value, dtype: float64
# count    159.000000
# mean       0.004193
# std        0.052870
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.666667
# Name: idcIP.value, dtype: float64
# -----------------------
#
#
#
# column:maxentID.1h.value description:
#
# count    159.000000
# mean       1.165514
# std        0.245934
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.333333
# max        2.200000
# Name: maxentID.1h.value, dtype: float64
# count    159.000000
# mean       1.165514
# std        0.245934
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.333333
# max        2.200000
# Name: maxentID.1h.value, dtype: float64
# -----------------------
#
#
#
# column:maxentID.5m.value description:
#
# count    159.000000
# mean       1.048041
# std        0.122191
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.500000
# Name: maxentID.5m.value, dtype: float64
# count    159.000000
# mean       1.048041
# std        0.122191
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.500000
# Name: maxentID.5m.value, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.1d.value description:
#
# count      159.000000
# mean      2808.976913
# std       2927.891931
# min          1.000000
# 25%        729.500000
# 50%       1677.500000
# 75%       3819.500000
# max      11149.500000
# Name: ipGeo.1d.value, dtype: float64
# count      159.000000
# mean      2808.976913
# std       2927.891931
# min          1.000000
# 25%        729.500000
# 50%       1677.500000
# 75%       3819.500000
# max      11149.500000
# Name: ipGeo.1d.value, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.7d.value description:
#
# count      159.000000
# mean     19089.232257
# std      19267.791496
# min          1.000000
# 25%       5004.000000
# 50%      11462.666667
# 75%      25989.000000
# max      74307.000000
# Name: ipGeo.7d.value, dtype: float64
# count      159.000000
# mean     19089.232257
# std      19267.791496
# min          1.000000
# 25%       5004.000000
# 50%      11462.666667
# 75%      25989.000000
# max      74307.000000
# Name: ipGeo.7d.value, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.15m.value description:
#
# count    159.000000
# mean      35.082104
# std       54.182075
# min        1.000000
# 25%        7.000000
# 50%       19.000000
# 75%       42.250000
# max      537.000000
# Name: ipGeo.15m.value, dtype: float64
# count    159.000000
# mean      35.082104
# std       54.182075
# min        1.000000
# 25%        7.000000
# 50%       19.000000
# 75%       42.250000
# max      537.000000
# Name: ipGeo.15m.value, dtype: float64
# -----------------------
#
#
#
# column:did.5m.value description:
#
# count    159.000000
# mean       1.041227
# std        0.109866
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.500000
# Name: did.5m.value, dtype: float64
# count    159.000000
# mean       1.041227
# std        0.109866
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.500000
# Name: did.5m.value, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.1h.value description:
#
# count    159.000000
# mean       9.813231
# std       16.828196
# min        1.000000
# 25%        1.291667
# 50%        3.000000
# 75%       10.500000
# max      120.000000
# Name: ipSeg24.1h.value, dtype: float64
# count    159.000000
# mean       9.813231
# std       16.828196
# min        1.000000
# 25%        1.291667
# 50%        3.000000
# 75%       10.500000
# max      120.000000
# Name: ipSeg24.1h.value, dtype: float64
# -----------------------
#
#
#
# column:maxentID.6h.value description:
#
# count    159.000000
# mean       1.225938
# std        0.314948
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max        2.500000
# Name: maxentID.6h.value, dtype: float64
# count    159.000000
# mean       1.225938
# std        0.314948
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max        2.500000
# Name: maxentID.6h.value, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.5m.value description:
#
# count    159.000000
# mean       1.681547
# std        1.477770
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.650000
# max       14.000000
# Name: ipSeg24.5m.value, dtype: float64
# count    159.000000
# mean       1.681547
# std        1.477770
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.650000
# max       14.000000
# Name: ipSeg24.5m.value, dtype: float64
# -----------------------
#
#
#
# column:did.7d.value description:
#
# count    159.000000
# mean       1.428196
# std        0.642202
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max        4.833333
# Name: did.7d.value, dtype: float64
# count    159.000000
# mean       1.428196
# std        0.642202
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max        4.833333
# Name: did.7d.value, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.5m.value description:
#
# count    159.000000
# mean      10.762393
# std       13.355102
# min        1.000000
# 25%        2.500000
# 50%        6.000000
# 75%       13.000000
# max      103.000000
# Name: ipGeo.5m.value, dtype: float64
# count    159.000000
# mean      10.762393
# std       13.355102
# min        1.000000
# 25%        2.500000
# 50%        6.000000
# 75%       13.000000
# max      103.000000
# Name: ipGeo.5m.value, dtype: float64
# -----------------------
#
#
#
# column:did.6h.value description:
#
# count    159.000000
# mean       1.188574
# std        0.286089
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.333333
# max        2.500000
# Name: did.6h.value, dtype: float64
# count    159.000000
# mean       1.188574
# std        0.286089
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.333333
# max        2.500000
# Name: did.6h.value, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.1h.value description:
#
# count     159.000000
# mean      143.288829
# std       172.029438
# min         1.000000
# 25%        28.500000
# 50%        79.000000
# 75%       192.625000
# max      1013.000000
# Name: ipGeo.1h.value, dtype: float64
# count     159.000000
# mean      143.288829
# std       172.029438
# min         1.000000
# 25%        28.500000
# 50%        79.000000
# 75%       192.625000
# max      1013.000000
# Name: ipGeo.1h.value, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.1d.value description:
#
# count     159.000000
# mean      167.344808
# std       288.407377
# min         1.000000
# 25%         3.000000
# 50%        50.000000
# 75%       203.500000
# max      1710.000000
# Name: ipSeg24.1d.value, dtype: float64
# count     159.000000
# mean      167.344808
# std       288.407377
# min         1.000000
# 25%         3.000000
# 50%        50.000000
# 75%       203.500000
# max      1710.000000
# Name: ipSeg24.1d.value, dtype: float64
# -----------------------
#
#
#
# column:maxentID.1m.value description:
#
# count    159.000000
# mean       1.016946
# std        0.074330
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.500000
# Name: maxentID.1m.value, dtype: float64
# count    159.000000
# mean       1.016946
# std        0.074330
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.500000
# Name: maxentID.1m.value, dtype: float64
# -----------------------
#
#
#
# column:maxentID.1d.value description:
#
# count    159.000000
# mean       1.281950
# std        0.367192
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max        2.666667
# Name: maxentID.1d.value, dtype: float64
# count    159.000000
# mean       1.281950
# std        0.367192
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max        2.666667
# Name: maxentID.1d.value, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.6h.value description:
#
# count    159.000000
# mean      54.439070
# std      100.177118
# min        1.000000
# 25%        1.625000
# 50%       13.800000
# 75%       66.333333
# max      724.000000
# Name: ipSeg24.6h.value, dtype: float64
# count    159.000000
# mean      54.439070
# std      100.177118
# min        1.000000
# 25%        1.625000
# 50%       13.800000
# 75%       66.333333
# max      724.000000
# Name: ipSeg24.6h.value, dtype: float64
# -----------------------
#
#
#
# column:did.1d.value description:
#
# count    159.000000
# mean       1.235676
# std        0.341117
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max        2.666667
# Name: did.1d.value, dtype: float64
# count    159.000000
# mean       1.235676
# std        0.341117
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max        2.666667
# Name: did.1d.value, dtype: float64
# -----------------------
#
#
#
# column:did.1m.value description:
#
# count    159.000000
# mean       1.016946
# std        0.074330
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.500000
# Name: did.1m.value, dtype: float64
# count    159.000000
# mean       1.016946
# std        0.074330
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.500000
# Name: did.1m.value, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.6h.value description:
#
# count     159.000000
# mean      869.019109
# std       993.611468
# min         1.000000
# 25%       162.333333
# 50%       494.000000
# 75%      1123.500000
# max      4386.000000
# Name: ipGeo.6h.value, dtype: float64
# count     159.000000
# mean      869.019109
# std       993.611468
# min         1.000000
# 25%       162.333333
# 50%       494.000000
# 75%      1123.500000
# max      4386.000000
# Name: ipGeo.6h.value, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.1m.value description:
#
# count    159.000000
# mean       1.088744
# std        0.279810
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: ipSeg24.1m.value, dtype: float64
# count    159.000000
# mean       1.088744
# std        0.279810
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: ipSeg24.1m.value, dtype: float64
# -----------------------
#
#
#
# column:ipGeo.1m.value description:
#
# count    159.000000
# mean       2.688833
# std        2.347762
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       17.000000
# Name: ipGeo.1m.value, dtype: float64
# count    159.000000
# mean       2.688833
# std        2.347762
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       17.000000
# Name: ipGeo.1m.value, dtype: float64
# -----------------------
#
#
#
# column:maxentID.15m.value description:
#
# count    159.000000
# mean       1.094262
# std        0.185365
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.045455
# max        2.000000
# Name: maxentID.15m.value, dtype: float64
# count    159.000000
# mean       1.094262
# std        0.185365
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.045455
# max        2.000000
# Name: maxentID.15m.value, dtype: float64
# -----------------------
#
#
#
# column:ipSeg24.7d.value description:
#
# count      159.000000
# mean      1131.815953
# std       1983.437935
# min          1.000000
# 25%         10.000000
# 50%        387.000000
# 75%       1368.000000
# max      12038.000000
# Name: ipSeg24.7d.value, dtype: float64
# count      159.000000
# mean      1131.815953
# std       1983.437935
# min          1.000000
# 25%         10.000000
# 50%        387.000000
# 75%       1368.000000
# max      12038.000000
# Name: ipSeg24.7d.value, dtype: float64
# -----------------------
#
#
#
# column:maxentID.7d.value description:
#
# count    159.000000
# mean       1.555789
# std        0.758198
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        1.800000
# max        4.833333
# Name: maxentID.7d.value, dtype: float64
# count    159.000000
# mean       1.555789
# std        0.758198
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        1.800000
# max        4.833333
# Name: maxentID.7d.value, dtype: float64
# -----------------------
#
#
#
# column:did.1h.value description:
#
# count    159.000000
# mean       1.137737
# std        0.217467
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.333333
# max        2.200000
# Name: did.1h.value, dtype: float64
# count    159.000000
# mean       1.137737
# std        0.217467
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.333333
# max        2.200000
# Name: did.1h.value, dtype: float64
# -----------------------
#
#
#
# column:did.15m.value description:
#
# count    159.000000
# mean       1.077805
# std        0.160256
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.750000
# Name: did.15m.value, dtype: float64
# count    159.000000
# mean       1.077805
# std        0.160256
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.750000
# Name: did.15m.value, dtype: float64
# -----------------------
#
#
#
# oline value cols is not same as local:
# []

# %% [markdown]
# 没有发生变化的value columns

# %% [markdown]
# - count columns检查

# %%
count_dif_cols = []
for col in count_cols:
    print("column:{0} description:\n".format(col))
    local_desc = df_ios_chk[col].describe()
    print(local_desc)
    ol_desc = df_ol_ios_chk[col].describe()
    print(ol_desc)
    if not np.allclose(local_desc.values,ol_desc.values,rtol=1e-6):
        print("!!!{0} desc is not same".format(col))
        count_dif_cols.append(col)
    print("-----------------------\n")
    print("\n")
print("oline value cols is not same as local:\n{0}".format(count_dif_cols))
# Out:
# column:mcid_counts description:
#
# count    159.000000
# mean       1.314465
# std        0.607322
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000
# Name: mcid_counts, dtype: float64
# count    158.000000
# mean       1.322785
# std        0.600095
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000
# Name: mcid_counts, dtype: float64
# !!!mcid_counts desc is not same
# -----------------------
#
#
#
# column:idfv_counts description:
#
# count    159.000000
# mean       1.754717
# std        1.344077
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        9.000000
# Name: idfv_counts, dtype: float64
# count    158.000000
# mean       1.765823
# std        1.341013
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        9.000000
# Name: idfv_counts, dtype: float64
# !!!idfv_counts desc is not same
# -----------------------
#
#
#
# column:idfa_counts description:
#
# count    159.000000
# mean       1.176101
# std        0.413913
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: idfa_counts, dtype: float64
# count    158.000000
# mean       1.183544
# std        0.404412
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: idfa_counts, dtype: float64
# !!!idfa_counts desc is not same
# -----------------------
#
#
#
# oline value cols is not same as local:
# ['mcid_counts', 'idfv_counts', 'idfa_counts']

# %% [markdown]
# 没有发生变化的count values:

# %%
loan_dif_cols = []
for col in loan_cols:
    print("column:{0} description:\n".format(col))
    local_desc = df_ios_chk[col].describe()
    print(local_desc)
    ol_desc = df_ol_ios_chk[col].describe()
    print(ol_desc)
    if not np.allclose(local_desc.values,ol_desc.values,rtol=1e-6):
        print("!!!{0} desc is not same".format(col))
        loan_dif_cols.append(col)
    print("-----------------------\n")
    print("\n")
print("oline value cols is not same as local:\n{0}".format(loan_dif_cols))
# Out:
# column:idfa_loan description:
#
# count    159.000000
# mean       0.433962
# std        0.497186
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: idfa_loan, dtype: float64
# count    155.000000
# mean       0.445161
# std        0.498595
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: idfa_loan, dtype: float64
# !!!idfa_loan desc is not same
# -----------------------
#
#
#
# oline value cols is not same as local:
# ['idfa_loan']

# %% [markdown]
# 多头借贷的数据一致

# %%
print(df_ios_chk['proxy_ua'].describe())
print(df_ol_ios_chk['proxy_ua'].describe())
# Out:
# count    159.000000
# mean       0.088050
# std        0.284263
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: proxy_ua, dtype: float64
# count    159.000000
# mean       0.088050
# std        0.284263
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: proxy_ua, dtype: float64

# %% [markdown]
# #### 结论：
# ios主要是anomaly的特征变化了，体现为均值标准差都变小，整体label为1的数量都是159

# %%
df_ios_chk.columns[df_ios_chk.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
df_ol_ios_chk.columns[df_ol_ios_chk.isnull().any()]
# Out:
# Index([u'idfa_loan', u'mcid_counts', u'idfa_counts', u'idfv_counts'], dtype='object')
